# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
print('all package are imported')
# Out:
# all package are imported

# %%
data=pd.read_csv('car data.csv')
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.shape
# Out:
# (301, 9)

# %%
print(data['Fuel_Type'].unique())
print(data['Seller_Type'].unique())
print(data['Transmission'].unique())
print(data['Owner'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
 #check missing or null values
data.isnull().sum()  #There are no missing values
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#more details about data
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#check columns
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
print('informations about the dataset')
data.info()
# Out:
# informations about the dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#a new dataset
new_data=data[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]
new_data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
new_data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
#add the new feature
new_data['current_year']=2021
new_data.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  current_year
# 0       Manual      0          2021
# 1       Manual      0          2021
# 2       Manual      0          2021
# 3       Manual      0          2021
# 4       Manual      0          2021

# %%
#the feature: the age of the car
new_data['nombre_of_years']=new_data['current_year']-new_data['Year']
new_data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  current_year  nombre_of_years
# ...

# %%
#drop the features year and current year
new_data.drop(['Year'],axis=1,inplace=True)
new_data.drop(['current_year'],axis=1,inplace=True)
new_data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  nombre_of_years
# 0       Manual      0                7
# 1       Manual      0                8
# 2       Manual      0                4
# 3       Manual      0               10
# 4       Manual      0                7

# %%
#convert the categorical feature in numbers
new_data=pd.get_dummies(new_data,drop_first=True)
new_data.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  nombre_of_years  \
# 0           3.35           5.59       27000      0                7
# 1           4.75           9.54       43000      0                8
# 2           7.25           9.85        6900      0                4
# 3           2.85           4.15        5200      0               10
# 4           4.60           6.87       42450      0                7
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
#correlation
new_data.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# nombre_of_years             -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         nombre_of_years  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price                 -0.236141          0.552339         -0.540571
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#visualisation
sns.set(style="ticks", color_codes=True)
sns.pairplot(new_data)

# %%
# !pip install matplotlib
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corrmap=new_data.corr()
#corr_features is the top correlation features
corr_features=corrmap.index
plt.figure(figsize=(20,20))
#in format of heatmap
gr=sns.heatmap(new_data[corr_features].corr(),annot=True,cmap='viridis')

# %%
#feature selection
X=new_data.iloc[:,1:]  #independent feature
Y=new_data.iloc[:,0]   #dependent feature
print('X',X.shape)
print('Y',Y.shape)
# Out:
# X (301, 8)
# Y (301,)

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  nombre_of_years  Fuel_Type_Diesel  \
# 0           5.59       27000      0                7                 0
# 1           9.54       43000      0                8                 1
# 2           9.85        6900      0                4                 0
# 3           4.15        5200      0               10                 0
# 4           6.87       42450      0                7                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
Y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
#feature importance
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,Y)
# Out:
# ExtraTreesRegressor()

# %%
 print(model.feature_importances_)
# Out:
# [0.42075979 0.03690815 0.00081499 0.07965593 0.19610239 0.01946239
#  0.12555386 0.12074248]

# %%
#visualization of features importances
feature_imp=pd.Series(model.feature_importances_,index=X.columns)
feature_imp.nlargest(7).plot(kind='barh')
plt.show()

# %%
#train_test_split
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train.shape
# Out:
# (240, 8)

# %%
#the model
from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()

# %%
#hyperparameters
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#RandomizedSearchCv applied for hyperparameters tuning
from sklearn.model_selection import RandomizedSearchCV

# %%
#number of trees in random forest
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
#number of features to consider at every split
max_features=['auto','sqrt']
#maximum number of levels in trees
max_depth=[int(x) for x in np.linspace(5,3,num=6)]
#minimum number of samples required to split a node
min_samples_split=[2,5,10,15,100]
#minimum number of samples required at each leaf node
min_samples_leaf=[1,2,5,10]

# %%
#create the random grid
random_grid={'n_estimators':n_estimators,
             'max_features':max_features,
             'max_depth':max_depth,
             'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 4, 4, 3, 3, 3], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
#use random grid to search for best hyperparameters
#create the base model to tune
rf=RandomForestRegressor()

# %%
#RandomizedSearchCv applied
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,scoring='neg_mean_squared_error',
                             n_iter=15,cv=5,verbose=2,
                            random_state=42,n_jobs=1)

# %%
rf_random.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   0.9s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   0.9s
# ...

# %%
#prediction
predictions=rf_random.predict(X_test)
predictions
# Out:
# array([ 0.38376867, 10.44054756,  0.38500525,  0.38500525,  1.1631862 ,
#         4.87171742,  5.64056815,  0.50842299,  4.7214685 ,  6.11422074,
#         0.59058308, 10.69256179,  5.17689866,  1.21519167,  1.01637617,
#         0.60153318,  5.20677216,  1.2899956 ,  6.28134704,  4.30285309,
#         0.30059051,  7.99319562,  0.5245053 ,  6.28539966,  2.89413189,
#        10.01158004, 20.30414507,  0.29683528,  4.66497946,  0.30707559,
#        20.27826861,  4.32097579,  4.87358197,  7.17989694,  6.92736129,
#         0.51127878,  5.55616261,  9.89249687,  2.74718867,  4.78936879,
#         6.94268571,  6.87227232, 19.49705817, 15.57128463,  7.04062824,
#         0.5636266 ,  4.79331229,  0.59985352,  5.15404337,  0.57668211,
#         5.38713531,  0.50685465,  3.98549444,  1.88231103,  3.17671983,
#         6.45290802,  5.09928637,  4.6992288 ,  7.48278593,  1.11696229,
#         0.57074605])

# %%
#visualize distribution
sns.distplot(Y_test-predictions) # a normal distribution
#the difference between y test and the prediction should be minimal,this what the graph tell us
# Out:
# <AxesSubplot:xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(Y_test,predictions)

# %%
#linearity of the graph : a good prediction

# %%
#save the model
import pickle
file=open('random_forest_regression_model.pkl','wb')
#dump information to the file
pickle.dump(rf_random,file)
#we will use this file in deployment
